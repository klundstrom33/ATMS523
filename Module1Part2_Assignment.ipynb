# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
def plot_stats(data, type):
    if type=='hist':
        sns.histplot(data)
    if type=='scatter':
        sns.scatterplot(data)
    return()

# %%
data_df=pd.DataFrame([np.random.rand(5), np.random.rand(5)], index=['Random 1', 'Random 2']).T
data_df
# Out:
#    Random 1  Random 2
# 0  0.440201  0.233678
# 1  0.995478  0.995373
# 2  0.913803  0.474241
# 3  0.635950  0.440134
# 4  0.046871  0.698321

# %%
plot_stats(data_df,'scatter')
# Out:
# ()

# %%
plot_stats(data_df,'hist')
# Out:
# ()
